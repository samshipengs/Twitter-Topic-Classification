# %%
from model_predictions import *

FILE_PATH = '/home/sam/Hhd/twitter_sentiment/'
# FILE_PATH = '/home/sam/Data/twitter_sentiment/'
# Out:
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:01:00.0)
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### All Four Airlines

# %%
ALL = Prediction(FILE_PATH, 'FOUR_AIRLINES.csv', max_len_train=19)
ALL.prepare_data(['text', 'airline'], wv_size=600)
# ALL.get_result(n_preview=10, n_top = 20, name='Total_result',verbose=False)
# Out:
# Loading csv: FOUR_AIRLINES.csv ...
# Note: pre-process changes the dataframe inplace.
# Loading existing model tweets600.model.bin ...
# Done building.
# max sentence length is:  20
# npy already exists, loading ...
# Done loading npy file.
# npy already exists.
# >>>Done preparing data.<<<

# %%
ALL.get_result(n_preview=10, n_top = 20, name='Total_result',verbose=False)
# Out:
# Loaded parameters to layer 'conv2d1' (shape 50x1x3x3).
# Loaded parameters to layer 'conv2d1' (shape 50x19x600).
# Loaded parameters to layer 'conv2d2' (shape 50x50x3x3).
# Loaded parameters to layer 'conv2d2' (shape 50x9x300).
# Loaded parameters to layer 'dense' (shape 30000x5000).
# Loaded parameters to layer 'dense' (shape 5000).
# Loaded parameters to layer 'output' (shape 5000x3).
# Loaded parameters to layer 'output' (shape 3).
# Extracting ...
# prediction
# Done converting numeric to categorical, this changes df.
# ===Positive===
# [('thanks', 80), ('thank', 60), ('great', 59), ('crew', 10), ('flying', 10), ('much', 9), ('flight', 9), ('fly', 8), ('team', 8), ('beautiful', 8), ('always', 8), ('got', 8), ('service', 8), ('well', 8), ('big', 8), ('welcome', 8), ('awesome', 7), ('home', 7), ('sent', 6), ('today', 6)]
# ===Neutral===
# ...

# %%
ALL.check(word='flight', sentiment=3, n_view=10)
# Out:
# @AirCanada Can I wear leggings during my flight? Just makin' sure I can. 😕😆
# Hey, @AirCanada - any reason you couldn't help out with the flight costs to make this event happen? #Indigenous https://t.co/Lfl6zu1Bna
# RT @abbeyshortpants: Hey @WestJet I tweeted @AirCanada but they never responded about a delayed flight. At least I know u would have. #cust…
# Hey @WestJet I tweeted @AirCanada but they never responded about a delayed flight. At least I know u would have. #customerservice #humourme
# Phew, @AirCanada to the rescue. Fired up to get on a flight that departs and arrives on time. #NotDelta
# Can you tell us why when someone has missed their connecting flight in Japan due to a 2hr delay @YVR and @AirCanada does nothing to help?
# Thanks to the great staff @clubsportifmaa for the workout before hitting a 6 hour @AirCanada flight. #ImpatientTraveller
# Frank @aircanada Laguardia. You rocked it today my friend. Thanks for squeezing us in on an earlier flight.
# ...

# %% [markdown]
# ### AmericanAir

# %%
# AA = GenerateData(FILE_PATH, 'Americanair.csv', max_len_train=19)
# AA.prepare_data(wv_size=600)
# AA.get_result(n_preview=10, n_top = 20, name='AA_result',verbose=False)

# %%
# AA.check(word='worst', sentiment=3, n_view=10)
